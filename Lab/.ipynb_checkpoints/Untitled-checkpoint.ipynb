# %% [markdown]
# # Vector Space Model
#
# Simple implementation, quite inefficient.

# %%
from collections import defaultdict
from math import log,sqrt #tf-idf
import re #regular expression

# %%
def import_dataset():
    articles = []
    with open('collections/TIME.ALL') as f:
        tmp = []
        for row in f:
            if row.startswith('*TEXT'):
                if tmp!= []:
                    articles.append(tmp)
                #empty collection of the terms we found so far
                tmp = []
            else:
                #keep only alphabetic strings
                row = re.sub(r'^a-zA-Z\s','', row)
                tmp += row.split()
        return articles

# %%
import_dataset()[2]
# Out:
# ['BERLIN',
#  'ONE',
#  'LAST',
#  'RUN',
#  'HANS',
#  'WEIDNER',
#  'HAD',
#  'BEEN',
#  'HOPING',
#  'FOR',
#  'MONTHS',
#  'TO',
#  'ESCAPE',
#  'DRAB',
#  'EAST',
#  'GERMANY',
#  'AND',
#  'MAKE',
#  'HIS',
#  'WAY',
#  'TO',
#  'THE',
#  'WEST',
#  '.',
#  'THE',
#  'ODDS',
#  'WERE',
#  'AGAINST',
#  'HIM,',
#  'FOR',
#  'WEIDNER,',
#  '40,',
#  'WAS',
#  'A',
#  'CRIPPLE',
#  'ON',
#  'CRUTCHES',
#  'WHO',
#  'LIVED',
#  'IN',
#  'THE',
#  'VILLAGE',
#  'OF',
#  'NEUGERSDORF,',
#  '115',
#  'MILES',
#  'SOUTHEAST',
#  'OF',
#  'THE',
#  'FRONTIER',
#  'OF',
#  'FREEDOM',
#  'BUT',
#  'HANS',
#  'WEIDNER',
#  'DID',
#  'HAVE',
#  'ONE',
#  'MAJOR',
#  'ASSET,',
#  'THE',
#  'BUS',
#  'THAT',
#  'HE',
#  'OPERATED',
#  'FOR',
#  'THE',
#  'LOCAL',
#  'COMMUNIST',
#  'REGIME',
#  '.',
#  'IT',
#  'WAS',
#  'AN',
#  'UGLY',
#  'THING,',
#  'AND',
#  'ANCIENT',
#  '.',
#  'ITS',
#  'CHASSIS',
#  'CREAKED,',
#  'AND',
#  'THE',
#  'ENGINE',
#  'COUGHED',
#  ';',
#  'A',
#  'CREAM-COLORED',
#  'COAT',
#  'OF',
#  'PAINT',
#  'COULD',
#  'NOT',
#  'DISGUISE',
#  'THE',
#  'WELTS',
#  'AND',
#  'BRUISES',
#  'OF',
#  'TWO',
#  'DECADES',
#  'OF',
#  'CHUGGING',
#  'SERVICE',
#  '.',
#  'IN',
#  'FACT,',
#  'THE',
#  'BUS',
#  'WAS',
#  'READY',
#  'FOR',
#  'THE',
#  'JUNK',
#  'PILE',
#  'WHEN',
#  'WEIDNER',
#  'DECIDED',
#  'TO',
#  'PRESS',
#  'IT',
#  'INTO',
#  'SERVICE',
#  'FOR',
#  'ONE',
#  'LAST',
#  'RUN',
#  '.',
#  'SHARP',
#  'BLADES',
#  '.',
#  'THE',
#  'HAZARDS',
#  'WOULD',
#  'BE',
#  'GREAT',
#  'ON',
#  'THE',
#  'JOURNEY',
#  'TO',
#  'THE',
#  'BORDER',
#  ';',
#  'SO',
#  'WEIDNER',
#  'SIGNED',
#  'UP',
#  'A',
#  'FELLOW',
#  'VILLAGER,',
#  'JURGEN',
#  'WAGNER,',
#  '22,',
#  'TO',
#  'TAKE',
#  'THE',
#  'WHEEL',
#  '.',
#  'EIGHT',
#  'DAYS',
#  'BEFORE',
#  'CHRISTMAS,',
#  'THE',
#  'PAIR',
#  'BEGAN',
#  'THE',
#  'FEVERISH',
#  'PREPARATIONS',
#  'IN',
#  "WEIDNER'S",
#  'GARAGE',
#  '.',
#  'FIRST',
#  'WEIDNER',
#  'AND',
#  'WAGNER',
#  'ATTACHED',
#  'A',
#  'HEAVY',
#  'SNOWPLOW',
#  'TO',
#  'THE',
#  'FRONT',
#  'OF',
#  'THE',
#  'BUS,',
#  'NOT',
#  'TO',
#  'PLOW',
#  'SNOW,',
#  'BUT',
#  'TO',
#  'SCOOP',
#  'AWAY',
#  'THE',
#  'HEAVY',
#  'OBSTACLES',
#  'THEY',
#  'KNEW',
#  'AWAITED',
#  'THEM',
#  'AT',
#  'ROADBLOCKS',
#  'AHEAD',
#  '.',
#  'TO',
#  'ALL',
#  'SIX',
#  'LUGS',
#  'ON',
#  'EACH',
#  'FRONT',
#  'WHEEL',
#  'THEY',
#  'BOLTED',
#  'SHARP',
#  'BLADES',
#  'OF',
#  'THE',
#  'TOUGHEST',
#  'STEEL,',
#  'AFFIXED',
#  'SO',
#  'THAT',
#  'THE',
#  'WHIRLING',
#  'EDGES',
#  'WOULD',
#  'CHOP',
#  'BARBED',
#  'WIRE',
#  'TO',
#  'BITS',
#  '.',
#  'THEN',
#  'THEY',
#  'WEDGED',
#  'ONE-QUARTER-INCH',
#  'SECTIONS',
#  'OF',
#  'STEEL',
#  'PLATE',
#  'INSIDE',
#  'THE',
#  'BUS',
#  'TO',
#  'STOP',
#  'BULLETS',
#  '.',
#  'AT',
#  'LAST',
#  'ALL',
#  'WAS',
#  'READY',
#  '.',
#  'ON',
#  'CHRISTMAS',
#  'EVE,',
#  'WEIDNER',
#  'AND',
#  'WAGNER',
#  'PILED',
#  'THEIR',
#  'WIVES',
#  'AND',
#  'FOUR',
#  'CHILDREN',
#  'ABOARD,',
#  'NOT',
#  'FORGETTING',
#  'THREE',
#  'TONS',
#  'OF',
#  'HOUSEHOLD',
#  'BELONGINGS',
#  '.',
#  'FOR',
#  'ADDED',
#  'PROTECTION',
#  'THE',
#  'PLOTTERS',
#  'SHOVELED',
#  'A',
#  'TON',
#  'OF',
#  'COAL',
#  'AND',
#  'POTATOES',
#  'INTO',
#  'THE',
#  'BACK',
#  'OF',
#  'THE',
#  'BUS',
#  '.',
#  'THEN',
#  'THEY',
#  'CHUGGED',
#  'OFF',
#  'NORTH',
#  'TOWARD',
#  'BERLIN',
#  'ALONG',
#  'BACK',
#  'ROADS',
#  'TO',
#  'ESCAPE',
#  'COMMUNIST',
#  'PATROLS',
#  '.',
#  'JUST',
#  'BEFORE',
#  'THEY',
#  'REACHED',
#  'THE',
#  'WALL,',
#  'THEY',
#  'PLANNED',
#  'TO',
#  'SWING',
#  'WEST',
#  'IN',
#  'ORDER',
#  'TO',
#  'ENTER',
#  'THE',
#  'EAST-WEST',
#  'AUTOBAHN',
#  'LEADING',
#  'TO',
#  'THE',
#  'U.S',
#  '.',
#  'SECTOR',
#  'OF',
#  'THE',
#  'CITY',
#  '.',
#  'EN',
#  'ROUTE,',
#  'THE',
#  'RADIATOR',
#  'FROZE',
#  'IN',
#  'THE',
#  'SUBZERO',
#  'WEATHER',
#  '.',
#  'THAT',
#  'FIXED,',
#  'THEY',
#  'WERE',
#  'ONLY',
#  'A',
#  'FEW',
#  'MILES',
#  'FARTHER',
#  'WHEN',
#  'A',
#  'TIRE',
#  'BLEW',
#  'OUT',
#  '.',
#  'THE',
#  'KIDS',
#  'WERE',
#  'CRYING',
#  'AND',
#  'THE',
#  'WIVES',
#  'SHIVERING',
#  'WITH',
#  'COLD',
#  'AND',
#  'PANIC',
#  'WHEN,',
#  'AT',
#  'LAST,',
#  'THEY',
#  'ARRIVED',
#  'AT',
#  'DREWITZ,',
#  'THE',
#  'MOST',
#  'HEAVILY',
#  'GUARDED',
#  'CHECKPOINT',
#  'ON',
#  'THE',
#  'ENTIRE',
#  'AUTOBAHN',
#  'TO',
#  'BERLIN',
#  '.',
#  'IT',
#  'WAS',
#  'NO',
#  'TIME',
#  'TO',
#  'STOP',
#  'AND',
#  'RECONSIDER',
#  '.',
#  'FLYING',
#  'POTATOES',
#  '.',
#  '"',
#  'WAH-AH,',
#  'WAH-AH,',
#  '"',
#  'SHRIEKED',
#  'THE',
#  'POLICE-TYPE',
#  'KLAXONS',
#  'THAT',
#  'WEIDNER',
#  'HAD',
#  'THOUGHTFULLY',
#  'INSTALLED',
#  'IN',
#  'ADVANCE',
#  '.',
#  'THE',
#  'COMMUNIST',
#  'GUARDS',
#  'OBEDIENTLY',
#  'RAISED',
#  'THE',
#  'FIRST',
#  'OF',
#  'THREE',
#  'BARRIERS',
#  '.',
#  'BUT',
#  'WHAT',
#  'WAS',
#  'A',
#  'BUS',
#  'DOING',
#  'ON',
#  'EMERGENCY',
#  'DUTY',
#  '?',
#  'SUDDENLY',
#  'THE',
#  'SHOOTING',
#  'BEGAN',
#  'TOO',
#  'LATE',
#  '.',
#  'WAGNER,',
#  'AT',
#  '40',
#  'M.P.H.,',
#  'WAS',
#  'ALREADY',
#  'CRASHING',
#  'THROUGH',
#  'THE',
#  'SECOND',
#  'BARRIER',
#  '100',
#  'YARDS',
#  'AHEAD,',
#  'THEN',
#  'THE',
#  'THIRD,',
#  'ONLY',
#  '20',
#  'YARDS',
#  'AWAY',
#  '.',
#  'ITS',
#  'WINDSHIELD',
#  'SMASHED,',
#  'ITS',
#  'PASSENGERS',
#  'SHAKEN,',
#  'ITS',
#  'CARGO',
#  'OF',
#  'COAL',
#  'AND',
#  'POTATOES',
#  'IN',
#  'EVERY',
#  'CORNER',
#  'OF',
#  'THE',
#  'CAB,',
#  'THE',
#  'OLD',
#  'BUS',
#  'FINALLY',
#  'LURCHED',
#  'TO',
#  'A',
#  'STOP',
#  'A',
#  'FEW',
#  'MILES',
#  'DOWN',
#  'THE',
#  'ROAD',
#  'WHERE',
#  'THE',
#  'COMMUNISTS',
#  'NO',
#  'LONGER',
#  'MATTERED',
#  'AT',
#  'THE',
#  'U.S',
#  '.',
#  'CHECKPOINT,',
#  'A',
#  'FOOT',
#  'OR',
#  'TWO',
#  'INSIDE',
#  'WEST',
#  'BERLIN',
#  '.']

# %% [markdown]
# We now want to index: we need term frequency.
#
# We also want to build positional index, for phrase queries.

# %%
def make_positional_index(articles):
    index = defaultdict(dict)
    for docid, article in enumerate(articles):
        #for each of the articles we can take the term and the position
        #in which the terms appear
        for pos, term in enumerate(article):
            try:
                index[term][docid].append(pos)
            except KeyError:
                index[term][docid] = [pos]
    return index

# %%
articles = import_dataset()
index = make_positional_index(articles)
index['BERLIN']
# Out:
# {2: [0, 302, 393, 522],
#  8: [379],
#  14: [158, 231],
#  46: [3880],
#  73: [160, 214],
#  80: [0, 14, 169, 192, 220],
#  205: [1, 65, 131, 249, 332, 490, 530],
#  271: [873],
#  278: [14, 179, 475, 666],
#  279: [69],
#  294: [680, 718],
#  298: [0, 14, 32],
#  305: [645, 651, 662],
#  315: [11, 115],
#  342: [3979],
#  363: [79],
#  366: [266, 507, 1346],
#  379: [263, 292],
#  401: [20],
#  414: [37, 143]}

# %%
#vector representing the document
def document_as_vectors(articles):
    p_index = make_positional_index(articles)
    vectors = [] #all the vectors representing all the documents
    n = len(articles)
    idf = {}
    for term in p_index.keys():
        idf[term] = log(n/len(p_index[term]))
    for docid in range(0, len(articles)):
        v = {}
        for term in p_index.keys():
            #for each term we have a component of this vector to fill
            try: 
                tfidf = len(p_index[term][docid]) * idf[term]
            except KeyError:
                tfidf = 0
            v[term] = tfidf
        #need to fill v with entry which contain the weight given by tfidf
        vectors.append(v)
    return vectors

# %%
vectors = document_as_vectors(articles)
vectors[0]
# Out:
# {'THE': 0.0,
#  'ALLIES': 5.355418968099076,
#  'AFTER': 1.9269837964911969,
#  'NASSAU': 12.75973753442387,
#  'IN': 0.023724803536303955,
#  'DECEMBER': 3.6471100412376414,
#  '1960,': 3.405947984420753,
#  'U.S': 13.03283372193274,
#  '.': 0.12336897838878057,
#  'FIRST': 3.4980852759914405,
#  'PROPOSED': 2.78690877601453,
#  'TO': 0.06405696954802068,
#  'HELP': 5.802394349588101,
#  'NATO': 12.44828626273299,
#  'DEVELOP': 7.931127544712352,
#  'ITS': 3.721035975097208,
#  'OWN': 3.87932599520874,
#  'NUCLEAR': 22.838051983424492,
#  'STRIKE': 5.287615864747713,
#  'FORCE': 13.009317649915312,
#  'BUT': 0.451807439313483,
#  'EUROPE': 4.187523190909169,
#  'MADE': 1.1774708635804294,
#  'NO': 3.0346300255640823,
#  'ATTEMPT': 2.5186447894198505,
#  'DEVISE': 5.351858133476067,
#  'A': 0.0,
#  'PLAN': 2.283805198342449,
#  'LAST': 0.39833882171774687,
#  'WEEK,': 1.0145673926435763,
#  'AS': 0.680298332735925,
#  'THEY': 1.3845270157629384,
#  'STUDIED': 3.965563772356176,
#  'ACCORD': 4.658710952916121,
#  'BETWEEN': 1.4006144148946391,
#  'PRESIDENT': 2.309312371628516,
#  'KENNEDY': 7.645493257708594,
#  'AND': 0.15238210418008866,
#  'PRIME': 3.3011123187271463,
#  'MINISTER': 2.192490847315687,
#  'MACMILLAN,': 7.931127544712352,
#  'EUROPEANS': 2.953962860677696,
#  'SAW': 3.0004828763125886,
#  'EMERGING': 4.4355674016019115,
#  'OUTLINES': 6.045005314036012,
#  'OF': 0.0,
#  'THAT': 1.4638327187893534,
#  'WANTS': 2.4614863755799017,
#  'WILL': 8.547438249247714,
#  'SUPPORT': 1.7683391950199565,
#  'IT': 1.616123475476617,
#  'ALL': 1.9837169165631678,
#  'SPRANG': 6.045005314036012,
#  'FROM': 0.8503729159199063,
#  'ANGLO-U.S': 6.045005314036012,
#  'CRISIS': 2.3073356957526436,
#  'OVER': 0.6931471805599453,
#  'CANCELLATION': 4.946393025367902,
#  'BUG-RIDDEN': 5.351858133476067,
#  'SKYBOLT': 13.306702204805735,
#  'MISSILE,': 4.946393025367902,
#  'OFFER': 14.547555490534311,
#  'SUPPLY': 2.712800803860808,
#  'BRITAIN': 11.553893115545012,
#  'FRANCE': 7.607482350577917,
#  'WITH': 0.5492352379046238,
#  'PROVED': 2.579269411236285,
#  'POLARIS': 20.02173067760281,
#  '(TIME,': 2.953962860677696,
#  'DEC': 3.8477807366997925,
#  '28)': 5.351858133476067,
#  'ONE': 0.7228510933946605,
#  'ALLIED': 7.294220082475283,
#  'LEADER': 1.6382860667717587,
#  'WHO': 1.3916473101224296,
#  'UNRESERVEDLY': 6.045005314036012,
#  'WELCOMED': 3.5600986642480112,
#  'WAS': 0.3878812994214631,
#  'HAROLD': 2.579269411236285,
#  'BY': 0.8542318838078731,
#  'THUS': 4.614671391505287,
#  'KEEPING': 3.154633556139847,
#  'SEPARATE': 3.154633556139847,
#  'DETERRENT': 11.227260663125898,
#  'FOR': 0.13381435044250867,
#  'HAD': 0.867789301347299,
#  'SAVED': 3.742420221041966,
#  'HIS': 1.0712235426162902,
#  'NECK': 4.658710952916121,
#  'BACK': 1.0410590080905526,
#  'NASSAU,': 4.946393025367902,
#  'BEAMED': 4.4355674016019115,
#  'NOW': 0.9451388862118134,
#  'WEAPON': 4.099095164980699,
#  '"': 1.8872552289656976,
#  'GENERATION': 3.480055956574475,
#  'TERMS': 2.826129489167811,
#  'ARE': 1.6682027636379764,
#  'VERY': 1.9018705876444792,
#  'GOOD': 1.556368944303872,
#  'MANY': 1.125024388207887,
#  'OTHER': 1.6601391128540526,
#  'BRITONS': 3.480055956574475,
#  'WERE': 1.1952084939834342,
#  'NOT': 1.6788852675070034,
#  'SO': 0.9151065991129382,
#  'SURE': 2.826129489167811,
#  'THOUGH': 3.674171245292925,
#  'GOVERNMENT': 1.3394538127036937,
#  'SHOULDER': 3.742420221041966,
#  'NONE': 2.677709484049538,
#  '$800': 4.946393025367902,
#  'MILLION': 3.2765721335435174,
#  'DEVELOPMENT': 3.0492730404820207,
#  'COST': 5.2220362191017315,
#  'POLARIS,': 6.045005314036012,
#  'HAS': 1.9276154913819532,
#  'ALREADY': 3.402399784364656,
#  'POURED': 3.0004828763125886,
#  '$28': 5.351858133476067,
#  'INTO': 1.145469280729074,
#  'HAVE': 1.4730060470709203,
#  'SPEND': 3.405947984420753,
#  'PERHAPS': 2.4340874013917873,
#  '$1': 4.946393025367902,
#  'BILLION': 3.0004828763125886,
#  'MORE': 1.0551048351426084,
#  'FLEET': 5.498336896063366,
#  'MISSILE-PACKING': 6.045005314036012,
#  'SUBMARINES': 8.506491689615913,
#  'AT': 0.953407695515137,
#  'BEST,': 4.658710952916121,
#  'BRITISH': 5.799541855605688,
#  'BE': 2.3394614016830295,
#  'ABLE': 2.3073356957526436,
#  'DESIGN,': 4.4355674016019115,
#  'BUILD': 2.749168448031683,
#  'PROVE': 3.0004828763125886,
#  'BEFORE': 1.0751920144600111,
#  '1970,': 4.658710952916121,
#  'THREE': 0.8576195081952568,
#  'YEARS': 0.8246494889576869,
#  "BRITAIN'S": 11.507225573945522,
#  'BOMBER': 9.892786050735804,
#  'PRESUMABLY': 3.0492730404820207,
#  'BECOME': 3.7722444613526798,
#  'OBSOLETE': 9.317421905832243,
#  'THEN': 1.1471655140851005,
#  'WHAT': 1.96482056201809,
#  '?': 3.2675347693042536,
#  'TORY': 2.953962860677696,
#  'BACKBENCHERS': 4.658710952916121,
#  'LOUDLY': 4.253245844807957,
#  'SKEPTICAL': 3.742420221041966,
#  'CALL': 2.0937615954545845,
#  'SMALL': 2.0560212674717375,
#  'TYPE': 3.8477807366997925,
#  'PACT,': 5.351858133476067,
#  'WHICH': 1.6312413104738546,
#  'STIPULATES': 6.045005314036012,
#  'SUBMARINE': 3.965563772356176,
#  'FLEET,': 8.871134803203823,
#  'EXCEPT': 5.57381755202906,
#  'WHEN': 1.3845270157629384,
#  'SUPREME': 3.965563772356176,
#  'NATIONAL': 4.201843244683918,
#  'INTERESTS': 10.680295992744034,
#  'INTERVENE,': 6.045005314036012,
#  'MUST': 1.8108988094387524,
#  'COMMITTED': 3.1005663348695713,
#  'TRULY': 4.253245844807957,
#  'MULTILATERAL': 7.931127544712352,
#  'DOES': 4.521631360235501,
#  'MEAN': 3.3369551129338015,
#  'EVENTUALLY': 3.1005663348695713,
#  'DECIDE': 3.3369551129338015,
#  'OR': 2.9469504665392283,
#  'WHETHER': 4.30637003185077,
#  'JUSTIFY': 5.351858133476067,
#  'WITHDRAWAL': 3.211791969979796,
#  'NATO,': 3.6471100412376414,
#  'PARTICULARLY': 3.154633556139847,
#  'IF': 3.5438000592859313,
#  'THOSE': 1.8861222306763399,
#  'CONFLICT': 3.5600986642480112,
#  'POLICY': 2.0937615954545845,
#  'BIGGEST': 2.579269411236285,
#  'QUESTION': 2.173804303128121,
#  'IS': 1.208765382027912,
#  "FRANCE'S": 10.444072438203463,
#  'INCLUSION': 5.351858133476067,
#  'DELIBERATE': 4.253245844807957,
#  'PLOY': 4.946393025367902,
#  'JACK': 3.965563772356176,
#  'END': 1.4298847971947524,
#  'LEAST': 3.4285439474993615,
#  'DOWNGRADE': 5.351858133476067,
#  'PRIZED': 5.351858133476067,
#  'SPECIAL': 2.3073356957526436,
#  'RELATIONSHIP': 4.4355674016019115,
#  'CARTOONISTS': 6.045005314036012,
#  'WENT': 1.5451956437057468,
#  'EVEN': 1.4933758949759501,
#  'FARTHER': 3.742420221041966,
#  'ONLY': 2.837107691149483,
#  'SHOWED': 2.283805198342449,
#  'SUPERMAC': 6.045005314036012,
#  'JUMPING': 5.351858133476067,
#  "SUPERJACK'S": 6.045005314036012,
#  'COMMANDS,': 5.351858133476067,
#  'DE': 19.300004601763828,
#  'GAULLE': 15.825709760824253,
#  'ADENAUER': 6.423583939959592,
#  'WELL': 3.003421063532016,
#  'EDITH': 6.045005314036012,
#  'SAID': 1.3862943611198906,
#  'FRENCH,': 3.8477807366997925,
#  'GOT': 1.470294335532629,
#  'DEVELOPING': 4.946393025367902,
#  'THEIR': 0.934992111414799,
#  'FRAPPE,': 4.946393025367902,
#  'QUICK': 3.3369551129338015,
#  'CROW': 5.351858133476067,
#  'VAUNTED': 4.658710952916121,
#  'TIES': 3.405947984420753,
#  'BROUGHT': 1.9178709289909204,
#  'NOTHING': 6.649091752640751,
#  'HUMILIATION': 4.946393025367902,
#  'CONTRAST,': 4.4355674016019115,
#  'BRAGGED': 5.351858133476067,
#  'FRENCH': 6.3163887815257125,
#  'OFFICIALS,': 4.099095164980699,
#  'FIASCO': 5.351858133476067,
#  'VINDICATED': 6.045005314036012,
#  'DECISION': 2.5484977525695314,
#  'BOMBS': 3.3369551129338015,
#  'DELIVERY': 4.099095164980699,
#  'SYSTEMS': 4.946393025367902,
#  'THUS,': 3.3369551129338015,
#  'CHARLES': 4.187523190909169,
#  'PROMISED': 2.3561258599220753,
#  'REFLECT': 4.946393025367902,
#  'ON': 0.39833882171774687,
#  'OFFER,': 4.4355674016019115,
#  'THERE': 0.6837131483265867,
#  'LITTLE': 1.224723748430975,
#  'LIKELIHOOD': 4.4355674016019115,
#  'HE': 0.4677286421186229,
#  'WOULD': 3.693958110489426,
#  'ACCEPT': 2.5186447894198505,
#  'ANY': 2.1783565128695024,
#  'SUBJECT': 3.405947984420753,
#  'CONTROL': 1.8108988094387524,
#  "GAULLE'S": 2.6110181095508658,
#  'UNSWERVING': 5.351858133476067,
#  'CONVICTION': 4.658710952916121,
#  'RUSSIANS': 4.922972751159803,
#  'ACTUALLY': 2.4340874013917873,
#  'INVADE': 5.351858133476067,
#  'WESTERN': 3.135336999115611,
#  'EUROPE,': 2.677709484049538,
#  'NATION': 1.8861222306763399,
#  'DIRECTLY': 3.3369551129338015,
#  'ATTACKED': 3.0004828763125886,
#  'MEANING': 3.480055956574475,
#  'INVITE': 5.351858133476067,
#  'DEVASTATION': 6.045005314036012,
#  'HELPING': 3.8477807366997925,
#  'UNLIKE': 3.211791969979796,
#  'FORCE,': 3.154633556139847,
#  'ALONG': 1.701199892182328,
#  'BEEN': 0.4728512818582472,
#  'PLEDGED': 3.6471100412376414,
#  'STRATEGIC': 6.0985460809640415,
#  'DETERRENT,': 4.099095164980699,
#  'FRAPPE': 8.198190329961397,
#  'RESPONSIBLE': 3.3369551129338015,
#  'DEFENSE': 1.7965100719866527,
#  'SAME': 1.6755574615689903,
#  'TIME,': 2.216363917546917,
#  'LONG': 1.3445249482435957,
#  'ARGUED': 3.0004828763125886,
#  'ATLANTIC': 3.0492730404820207,
#  'ALLIANCE': 5.733902967376133,
#  'COULD': 3.408193852583206,
#  'RUN': 2.216363917546917,
#  'MOST': 0.7171291452464307,
#  'EFFICIENTLY': 4.4355674016019115,
#  'TRIUMVIRATE': 5.351858133476067,
#  'INCLUDE': 3.480055956574475,
#  'AN': 0.5285235964873649,
#  'EQUAL': 3.480055956574475,
#  'THIS': 1.7819005814109337,
#  'MAJOR,': 6.045005314036012,
#  'UNSPOKEN,': 6.045005314036012,
#  'CONDITIONS': 3.211791969979796,
#  'MEMBERSHIP': 3.154633556139847,
#  'COMMON': 1.8553505720095862,
#  'MARKET': 2.0937615954545845,
#  ';': 0.615659685081571,
#  'SUGGESTED': 4.712251719844151,
#  'POINTEDLY': 4.099095164980699,
#  'MACMILLAN': 5.733902967376133,
#  'SHARE': 2.712800803860808,
#  'ADVANCED': 3.5600986642480112,
#  'MISSILE': 3.480055956574475,
#  'TECHNOLOGY': 4.4355674016019115,
#  'REPLIED': 2.6438079323738566,
#  'NONCOMMITTALLY': 6.045005314036012,
#  'DISCUSS': 3.742420221041966,
#  'KENNEDY,': 3.405947984420753,
#  'TOLD': 1.7545458728876207,
#  'GUEST': 3.965563772356176,
#  'HAUTEUR': 6.045005314036012,
#  'CASE': 2.283805198342449,
#  'DO': 1.470294335532629,
#  'EASE': 3.8477807366997925,
#  'ENTRY': 3.742420221041966,
#  'GO-IT-ALONE': 12.090010628072024,
#  'GRANDEUR': 9.317421905832243,
#  'KONRAD': 3.1005663348695713,
#  'ADENAUER,': 3.8477807366997925,
#  'HAND,': 3.154633556139847,
#  'FEARFUL': 3.6471100412376414,
#  'SNAP': 4.946393025367902,
#  'UP': 0.42460444831886174,
#  'WAY': 1.420032500751741,
#  'ACHIEVE': 3.0004828763125886,
#  'GOAL': 3.8477807366997925,
#  'THREE-NATION': 6.045005314036012,
#  'DIRECTORATE': 5.351858133476067,
#  'VOWED': 4.099095164980699,
#  '1954': 3.965563772356176,
#  'MANUFACTURE': 5.351858133476067,
#  'WEAPONS,': 3.480055956574475,
#  'INCREASINGLY': 2.677709484049538,
#  'APPREHENSIVE': 5.351858133476067,
#  'WITHOUT': 3.135336999115611,
#  'THEM,': 2.953962860677696,
#  'SAY': 2.153185015925385,
#  'USE,': 4.946393025367902,
#  'WEST': 1.2166915767337108,
#  'GERMANY': 2.037672128803541,
#  'RELEGATED': 4.946393025367902,
#  'SECOND-CLASS': 5.351858133476067,
#  'CITIZENSHIP': 4.658710952916121,
#  'WEEK': 0.7640896678001317,
#  'OFFICIAL': 3.135336999115611,
#  'BULLETIN': 5.351858133476067,
#  'REVIVED': 4.658710952916121,
#  'OLD,': 3.965563772356176,
#  'BITTER': 2.4614863755799017,
#  'CRY': 3.6471100412376414,
#  'PLEAS': 4.099095164980699,
#  'GREATER': 2.712800803860808,
#  'RELIANCE': 6.045005314036012,
#  'CONVENTIONAL': 8.198190329961397,
#  'FORCES': 2.0560212674717375,
#  'AIMED': 3.211791969979796,
#  'RAISING': 4.099095164980699,
#  'GERMAN': 2.173804303128121,
#  'CANNON': 4.253245844807957,
#  'FODDER': 6.045005314036012,
#  'ATOMIC': 3.480055956574475,
#  'KNIGHTS': 6.045005314036012,
#  'FROSTY': 6.045005314036012,
#  'LETTER': 3.2724165917962305,
#  'CHANCELLOR': 2.8669514836880663,
#  'GERMANY,': 5.733902967376133,
#  'SUPPLIES': 3.480055956574475,
#  'ALMOST': 1.740940220831842,
#  '50': 2.407419154309626,
#  'PER': 2.782089927756977,
#  'CENT': 2.961314245136351,
#  'GROUND': 2.5484977525695314,
#  'STRENGTH,': 3.8477807366997925,
#  'INTEND': 4.658710952916121,
#  'RAISE': 3.0492730404820207,
#  'DIVISIONS': 4.4355674016019115,
#  'WARFARE': 3.742420221041966,
#  'YET': 2.037672128803541,
#  'PLANNERS': 4.658710952916121,
#  'REASON': 2.3814436679063653,
#  'CREDIBLE': 6.045005314036012,
#  'SOVIET': 3.1581943907628562,
#  'ATTACK': 2.3073356957526436,
#  'STRONG': 2.6110181095508658,
#  'ARMY': 1.4806571225681755,
#  'GROUND,': 3.8477807366997925,
#  'BACKED': 2.749168448031683,
#  'VAST': 2.712800803860808,
#  'ARSENAL': 5.351858133476067,
#  'FACT': 2.037672128803541,
#  'IS,': 2.712800803860808,
#  'WEAPONS': 2.712800803860808,
#  'NEVER': 1.6382860667717587,
#  'USED': 2.0560212674717375,
#  'INDEPENDENTLY': 5.351858133476067,
#  'AGAINST': 0.9330175256794686,
#  'RUSSIA': 1.7965100719866527,
#  'INVITING': 4.658710952916121,
#  'DEVASTATING': 4.946393025367902,
#  'RETALIATION': 4.4355674016019115,
#  'EFFORTS,': 6.045005314036012,
#  'MANAGED': 2.6110181095508658,
#  'CREATE': 3.2724165917962305,
#  'CAPACITY': 4.099095164980699,
#  'REPRESENTS': 3.965563772356176,
#  '4': 3.5600986642480112,
#  'POWER': 1.4911284224354708,
#  'JUST': 1.2328209586635943,
#  'DAMNED': 4.253245844807957,
#  'NUISANCE,': 6.045005314036012,
#  'STATE': 1.291415122929647,
#  'DEPARTMENT': 3.0004828763125886,
#  'MEANS': 2.677709484049538,
#  'MILITARILY': 4.658710952916121,
#  'WE': 0.9270115016192567,
#  'EXPECTED': 4.814838308619252,
#  'BAIL': 6.045005314036012,
#  'OUT': 0.46905621088969557,
#  'COUNTRY': 1.3000731856727619,
#  'THROWS': 5.351858133476067,
#  'PEA': 6.045005314036012,
#  'ANYONE': 2.677709484049538,
#  'ELSE': 2.6438079323738566,
#  'HARDLY': 2.4614863755799017,
#  'AGREE,': 6.045005314036012,
#  'UNTIL': 1.5232167369869716,
#  'BECOMES': 3.8477807366997925,
#  'MAKES': 3.0492730404820207,
#  'IMMEDIATE': 3.0004828763125886,
#  'SENSE': 3.0004828763125886,
#  'EVENTUALLY,': 4.658710952916121,
#  'FRANCE,': 2.677709484049538,
#  'TOO,': 3.965563772356176,
#  'MAY': 1.4298847971947524,
#  'FIND': 2.238342824265692,
#  'NATO-CONTROLLED': 6.045005314036012,
#  'POSSIBLE': 2.3073356957526436,
#  'SUCCESSOR,': 4.4355674016019115,
#  'EUROPEAN': 2.037672128803541,
#  'MINUTEMAN': 6.045005314036012,
#  'ARSENAL,': 6.045005314036012,
#  'ANSWER': 2.677709484049538,
#  'SPIRALING': 5.351858133476067,
#  'DIMINISHING': 4.253245844807957,
#  'VALUE': 4.253245844807957,
#  "WHO'S": 0,
#  'CHARGE': 0,
#  'HERE': 0,
#  'NIKITA': 0,
#  'KHRUSHCHEV': 0,
#  'LAUNCHED': 0,
#  'GRANDIOSE': 0,
#  'VIRGIN': 0,
#  'LANDS': 0,
#  'GAMBLE': 0,
#  'PART': 0,
#  'PLOW': 0,
#  '32': 0,
#  'ACRES': 0,
#  'MARGINAL': 0,
#  'LAND': 0,
#  'KAZAKHSTAN,': 0,
#  'SETTLE': 0,
#  'COMMUNIST': 0,
#  'PIONEERS,': 0,
#  'PLANT': 0,
#  'PRODUCE': 0,
#  'HUGE': 0,
#  'QUANTITIES': 0,
#  'DESPERATELY': 0,
#  'NEEDED': 0,
#  'GRAIN': 0,
#  'WITHIN': 0,
#  'TWO': 0,
#  "NIKITA'S": 0,
#  'SCHEME': 0,
#  'FLOPPED': 0,
#  'ENOUGH': 0,
#  'RAINFALL,': 0,
#  'PIONEERS': 0,
#  'DID': 0,
#  'TAKE': 0,
#  'TRACTOR': 0,
#  'LIFE': 0,
#  'BLEAK': 0,
#  'FRONTIER': 0,
#  '1958,': 0,
#  'EACH': 0,
#  'HARVEST': 0,
#  'LOWER': 0,
#  'THAN': 0,
#  'PREVIOUS': 0,
#  "YEAR'S": 0,
#  'WORST': 0,
#  'YEAR': 0,
#  '1962,': 0,
#  'DELIVERED': 0,
#  'HALF': 0,
#  'QUOTAS': 0,
#  'NATURALLY,': 0,
#  'TAKES': 0,
#  'BLAME': 0,
#  'AGO': 0,
#  'FOUND': 0,
#  'SCAPEGOAT': 0,
#  'KAZAKHSTAN': 0,
#  'PARTY': 0,
#  'BOSS': 0,
#  'NIKOLAI': 0,
#  'BELYAEV,': 0,
#  'FIRED': 0,
#  'HIM': 0,
#  'ERRORS': 0,
#  "BELYAEV'S": 0,
#  'DINMUKHAMED': 0,
#  'KUNAEV,': 0,
#  'SIMILARLY': 0,
#  'BOUNCED': 0,
#  'LAPSES': 0,
#  'WORK': 0,
#  'MEASURE,': 0,
#  'MOSCOW': 0,
#  'ALSO': 0,
#  'PURGED': 0,
#  'FORMER': 0,
#  'PREMIER': 0,
#  'TERRITORY': 0,
#  'LOCAL': 0,
#  "PARTY'S": 0,
#  'CENTRAL': 0,
#  'COMMITTEE': 0,
#  'COINCIDENCE': 0,
#  'IGNATOV,': 0,
#  '61,': 0,
#  'ONETIME': 0,
#  'CRONY,': 0,
#  'ABRUPTLY': 0,
#  'LEFT': 0,
#  'POST': 0,
#  'DEPUTY': 0,
#  'NINE': 0,
#  'MONTHS': 0,
#  'JOB': 0,
#  'FARM': 0,
#  'EXPERT': 0,
#  'IGNATOV': 0,
#  'MISFORTUNE': 0,
#  'BOOST': 0,
#  'FOOD': 0,
#  'PRODUCTION': 0,
#  'BERLIN': 0,
#  'HANS': 0,
#  'WEIDNER': 0,
#  'HOPING': 0,
#  'ESCAPE': 0,
#  'DRAB': 0,
#  'EAST': 0,
#  'MAKE': 0,
#  'ODDS': 0,
#  'HIM,': 0,
#  'WEIDNER,': 0,
#  '40,': 0,
#  'CRIPPLE': 0,
#  'CRUTCHES': 0,
#  'LIVED': 0,
#  'VILLAGE': 0,
#  'NEUGERSDORF,': 0,
#  '115': 0,
#  'MILES': 0,
#  'SOUTHEAST': 0,
#  'FREEDOM': 0,
#  'MAJOR': 0,
#  'ASSET,': 0,
#  'BUS': 0,
#  'OPERATED': 0,
#  'REGIME': 0,
#  'UGLY': 0,
#  'THING,': 0,
#  'ANCIENT': 0,
#  'CHASSIS': 0,
#  'CREAKED,': 0,
#  'ENGINE': 0,
#  'COUGHED': 0,
#  'CREAM-COLORED': 0,
#  'COAT': 0,
#  'PAINT': 0,
#  'DISGUISE': 0,
#  'WELTS': 0,
#  'BRUISES': 0,
#  'DECADES': 0,
#  'CHUGGING': 0,
#  'SERVICE': 0,
#  'FACT,': 0,
#  'READY': 0,
#  'JUNK': 0,
#  'PILE': 0,
#  'DECIDED': 0,
#  'PRESS': 0,
#  'SHARP': 0,
#  'BLADES': 0,
#  'HAZARDS': 0,
#  'GREAT': 0,
#  'JOURNEY': 0,
#  'BORDER': 0,
#  'SIGNED': 0,
#  'FELLOW': 0,
#  'VILLAGER,': 0,
#  'JURGEN': 0,
#  'WAGNER,': 0,
#  '22,': 0,
#  'WHEEL': 0,
#  'EIGHT': 0,
#  'DAYS': 0,
#  'CHRISTMAS,': 0,
#  'PAIR': 0,
#  'BEGAN': 0,
#  'FEVERISH': 0,
#  'PREPARATIONS': 0,
#  "WEIDNER'S": 0,
#  'GARAGE': 0,
#  'WAGNER': 0,
#  'ATTACHED': 0,
#  'HEAVY': 0,
#  'SNOWPLOW': 0,
#  'FRONT': 0,
#  'BUS,': 0,
#  'SNOW,': 0,
#  'SCOOP': 0,
#  'AWAY': 0,
#  'OBSTACLES': 0,
#  'KNEW': 0,
#  'AWAITED': 0,
#  'THEM': 0,
#  'ROADBLOCKS': 0,
#  'AHEAD': 0,
#  'SIX': 0,
#  'LUGS': 0,
#  'BOLTED': 0,
#  'TOUGHEST': 0,
#  'STEEL,': 0,
#  'AFFIXED': 0,
#  'WHIRLING': 0,
#  'EDGES': 0,
#  'CHOP': 0,
#  'BARBED': 0,
#  'WIRE': 0,
#  'BITS': 0,
#  'WEDGED': 0,
#  'ONE-QUARTER-INCH': 0,
#  'SECTIONS': 0,
#  'STEEL': 0,
#  'PLATE': 0,
#  'INSIDE': 0,
#  'STOP': 0,
#  'BULLETS': 0,
#  'CHRISTMAS': 0,
#  'EVE,': 0,
#  'PILED': 0,
#  'WIVES': 0,
#  'FOUR': 0,
#  'CHILDREN': 0,
#  'ABOARD,': 0,
#  'FORGETTING': 0,
#  'TONS': 0,
#  'HOUSEHOLD': 0,
#  'BELONGINGS': 0,
#  'ADDED': 0,
#  'PROTECTION': 0,
#  'PLOTTERS': 0,
#  'SHOVELED': 0,
#  'TON': 0,
#  'COAL': 0,
#  'POTATOES': 0,
#  'CHUGGED': 0,
#  'OFF': 0,
#  'NORTH': 0,
#  'TOWARD': 0,
#  'ROADS': 0,
#  'PATROLS': 0,
#  'REACHED': 0,
#  'WALL,': 0,
#  'PLANNED': 0,
#  'SWING': 0,
#  'ORDER': 0,
#  'ENTER': 0,
#  'EAST-WEST': 0,
#  'AUTOBAHN': 0,
#  'LEADING': 0,
#  'SECTOR': 0,
#  'CITY': 0,
#  'EN': 0,
#  'ROUTE,': 0,
#  'RADIATOR': 0,
#  'FROZE': 0,
#  'SUBZERO': 0,
#  'WEATHER': 0,
#  'FIXED,': 0,
#  'FEW': 0,
#  'TIRE': 0,
#  'BLEW': 0,
#  'KIDS': 0,
#  'CRYING': 0,
#  'SHIVERING': 0,
#  'COLD': 0,
#  'PANIC': 0,
#  'WHEN,': 0,
#  'LAST,': 0,
#  'ARRIVED': 0,
#  'DREWITZ,': 0,
#  'HEAVILY': 0,
#  'GUARDED': 0,
#  'CHECKPOINT': 0,
#  'ENTIRE': 0,
#  'TIME': 0,
#  'RECONSIDER': 0,
#  'FLYING': 0,
#  'WAH-AH,': 0,
#  'SHRIEKED': 0,
#  'POLICE-TYPE': 0,
#  'KLAXONS': 0,
#  'THOUGHTFULLY': 0,
#  'INSTALLED': 0,
#  'ADVANCE': 0,
#  'GUARDS': 0,
#  'OBEDIENTLY': 0,
#  'RAISED': 0,
#  'BARRIERS': 0,
#  'DOING': 0,
#  'EMERGENCY': 0,
#  'DUTY': 0,
#  'SUDDENLY': 0,
#  'SHOOTING': 0,
#  'TOO': 0,
#  'LATE': 0,
#  '40': 0,
#  'M.P.H.,': 0,
#  'CRASHING': 0,
#  'THROUGH': 0,
#  'SECOND': 0,
#  'BARRIER': 0,
#  '100': 0,
#  'YARDS': 0,
#  'AHEAD,': 0,
#  'THIRD,': 0,
#  '20': 0,
#  'WINDSHIELD': 0,
#  'SMASHED,': 0,
#  'PASSENGERS': 0,
#  'SHAKEN,': 0,
#  'CARGO': 0,
#  'EVERY': 0,
#  'CORNER': 0,
#  'CAB,': 0,
#  'OLD': 0,
#  'FINALLY': 0,
#  'LURCHED': 0,
#  'DOWN': 0,
#  'ROAD': 0,
#  'WHERE': 0,
#  'COMMUNISTS': 0,
#  'LONGER': 0,
#  'MATTERED': 0,
#  'CHECKPOINT,': 0,
#  'FOOT': 0,
#  'JAIL': 0,
#  'PAVED': 0,
#  'NONOBJECTIVE': 0,
#  'ART': 0,
#  'SINCE': 0,
#  "KREMLIN'S": 0,
#  'SHARPEST': 0,
#  'BARBS': 0,
#  'THESE': 0,
#  'MODERN': 0,
#  'ESPIONAGE,': 0,
#  'MATTER': 0,
#  "KGB'S": 0,
#  'COPS': 0,
#  'TURN': 0,
#  'VICTIM': 0,
#  'WHOSE': 0,
#  'WRONGDOINGS': 0,
#  'COMBINED': 0,
#  'BOTH': 0,
#  'EVILS': 0,
#  'TURNED': 0,
#  'LENINGRAD': 0,
#  'PHYSICS': 0,
#  'TEACHER': 0,
#  'TASTE': 0,
#  'ABSTRACT': 0,
#  'PAINTING': 0,
#  'ALLEGEDLY': 0,
#  'LED': 0,
#  'JOIN': 0,
#  'SPY': 0,
#  'POLICE': 0,
#  'SPOTTED': 0,
#  'TEACHER,': 0,
#  'RUDOLF': 0,
#  'FRIEDMAN,': 0,
#  'MUTTERED': 0,
#  'UNCOMPLIMENTARY': 0,
#  'REMARKS': 0,
#  'ABOUT': 0,
#  'SOCIALIST': 0,
#  'REALISM': 0,
#  'WHILE': 0,
#  'STROLLING': 0,
#  "LENINGRAD'S": 0,
#  'RUSSIAN': 0,
#  'MUSEUM': 0,
#  'WELL-DRESSED': 0,
#  'TOURIST': 0,
#  'APPROACHED': 0,
#  'ENTHUSIASTICALLY': 0,
#  'SHARED': 0,
#  'SENTIMENTS,': 0,
#  'SEND': 0,
#  'FRIEDMAN': 0,
#  'REPRODUCTIONS': 0,
#  'AVANT-GARDE': 0,
#  'PAINTINGS': 0,
#  'AMERICA': 0,
#  'PICTURE': 0,
#  'LIKED': 0,
#  'INDIGNANTLY,': 0,
#  'CHAOS': 0,
#  'BLACK,': 0,
#  'RED': 0,
#  'BLUE': 0,
#  'SPLOTCHES': 0,
#  'CAPTIONED': 0,
#  'I': 0,
#  'NEED': 0,
#  'YOU': 0,
#  'TONIGHT': 0,
#  'SOON,': 0,
#  'SAID,': 0,
#  'GETTING': 0,
#  'MESSAGES': 0,
#  'WRITTEN': 0,
#  'INVISIBLE': 0,
#  'INK': 0,
#  'PREPARED': 0,
#  'DELIVER': 0,
#  'INFORMATION': 0,
#  'REMOTE': 0,
#  'THEORETICAL': 0,
#  'ARGUMENTS': 0,
#  'ART,': 0,
#  'POLICEMOVED': 0,
#  'HUSTLED': 0,
#  'CONGO': 0,
#  'ROUND': 0,
#  '3': 0,
#  'SOUND': 0,
#  'KATANGA': 0,
#  'PROVINCE': 0,
#  'THUNK': 0,
#  'MORTAR': 0,
#  'SHELLS': 0,
#  'RATTLE': 0,
#  'MACHINE': 0,
#  'GUNS': 0,
#  'UNEASY': 0,
#  'TWELVE-MONTH': 0,
#  'TRUCE': 0,
#  'U.N': 0,
#  'TROOPS': 0,
#  "KATANGA'S": 0,
#  'SECESSIONIST': 0,
#  'MOISE': 0,
#  'TSHOMBE,': 0,
#  'MINOR': 0,
#  'INCIDENTS': 0,
#  'THIRD': 0,
#  'SEPTEMBER': 0,
#  '1961': 0,
#  'TURMOIL': 0,
#  'BLUE-HELMETED': 0,
#  'SOLDIERS': 0,
#  'SWARMED': 0,
#  'ELISABETHVILLE,': 0,
#  'SEIZED': 0,
#  'HIGHWAYS': 0,
#  'SWEDISH': 0,
#  'SAAB': 0,
#  'JETS': 0,
#  'SWOOPED': 0,
#  'LOW': 0,
#  'AIRFIELD': 0,
#  'KOLWEZI,': 0,
#  'DESTROYING': 0,
#  'PLANES': 0,
#  'SETTING': 0,
#  'OIL': 0,
#  'TANKS': 0,
#  'ABLAZE': 0,
#  'SKIRMISHES,': 0,
#  'SEVEN': 0,
#  'DEAD': 0,
#  'FIGHTING': 0,
#  'ELISABETHVILLE': 0,
#  'RESIDENTS': 0,
#  "L'AFFAIRE": 0,
#  'SIMBA': 0,
#  'REFERENCE': 0,
#  'BEER,': 0,
#  'BREW': 0,
#  'SIDES': 0,
#  'GUZZLED': 0,
#  'IT,': 0,
#  'BOOZED-UP': 0,
#  'KATANGESE': 0,
#  'GENDARMES': 0,
#  'OPENED': 0,
#  'FIRE': 0,
#  'DETACHMENT': 0,
#  'ETHIOPIAN': 0,
#  'SUBURBAN': 0,
#  'LUBUMBASHI': 0,
#  'TSHOMBE': 0,
#  'DESCRIBED': 0,
#  'MATTERS,': 0,
#  'TIPSY': 0,
#  'ETHIOPIANS': 0,
#  'STARTED': 0,
#  'SCRAMBLING': 0,
#  'ATOP': 0,
#  '200-FT': 0,
#  'SLAG': 0,
#  'HEAP': 0,
#  'OUTSIDE': 0,
#  'BIG': 0,
#  'UNION': 0,
#  'MINIERE': 0,
#  'TAKING': 0,
#  'POTSHOTS': 0,
#  'FIREWORKS': 0,
#  'NEXT': 0,
#  'CASE,': 0,
#  'GOLF': 0,
#  'COURSE': 0,
#  'OUTSKIRTS': 0,
#  'TOOK': 0,
#  'OCCASION': 0,
#  'SHOOT': 0,
#  'UNARMED': 0,
#  'HELICOPTER': 0,
#  'MOVING': 0,
#  'OVERHEAD': 0,
#  'STONED': 0,
#  'SURVIVING': 0,
#  'CREWMEN,': 0,
#  'PUMMELED': 0,
#  'RIFLE': 0,
#  'BUTTS': 0,
#  '23-YEAR-OLD': 0,
#  'SIKH': 0,
#  'LIEUTENANT,': 0,
#  'LAY': 0,
#  'HELPLESS': 0,
#  'GUN': 0,
#  'SLUG': 0,
#  'ABDOMEN,': 0,
#  'DIED': 0,
#  'UNATTENDED': 0,
#  'HOURS': 0,
#  'INDIAN': 0,
#  'BRIGADIER': 0,
#  'REGINALD': 0,
#  'NORONHA,': 0,
#  'COMMANDER': 0,
#  'CAPITAL,': 0,
#  'FURIOUS': 0,
#  'GOING': 0,
#  'NORONHA': 0,
#  'WAIT': 0,
#  'LATER': 0,
#  'GUARD': 0,
#  'WARNING': 0,
#  'SHOT': 0,
#  'SOLDIER': 0,
#  'APPROACHING': 0,
#  'UNHURT,': 0,
#  'ROLLED': 0,
#  'HILL': 0,
#  'SEARCH': 0,
#  'COVER,': 0,
#  'COMRADES': 0,
#  'THOUGHT': 0,
#  'HIT': 0,
#  'SOON': 0,
#  'POSITIONS': 0,
#  'AROUND': 0,
#  'UNDER': 0,
#  ...}

# %%
def show_document_vector(v, docid):
    #we want to remove all the zero terms
    non_zero_terms = [x for x in v[docid].keys() if v[docid][x]>0]
    vector = [(x,v[docid][x]) for x in non_zero_terms]
    vector.sort(key=lambda x: x[1], reverse=True)
    length = sqrt(sum([x[1]**2 for x in vector]))
    normalized = {k: tfidf/length for k,tfidf in vector}
    for(term, tfidf) in vector:
        print(f"{term}:\t{tfidf}\t(normalized:{normalized[term]})")
